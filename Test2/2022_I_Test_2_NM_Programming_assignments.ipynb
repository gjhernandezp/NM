# %% [markdown]
# # **Numerical Methods Second Test**

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# # **1. Find the coefficients of the Vandermonde interpolation polinomial**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Alexandre-Théophile Vandermonde (28 February 1735 – 1 January 1796) was a French mathematician, musician and chemist who worked with Bézout and Lavoisier; his name is now principally associated with determinant theory in mathematics. He was born in Paris, and died there.
#
# https://en.wikipedia.org/wiki/Alexandre-Th%C3%A9ophile_Vandermonde

# %% [markdown]
# Consider a  set of points set of $n+1$ points $(x_0,y_0),(x_1,y_1),\dots,(x_n,y_n)$ find the coeficients $a_0,a_1,\cdots,a_n$ of the Vandermonde intepolation polinomial
#
# $$
# P_n(x) = a_0 + a_1 x + \cdots + a_n x^n
# $$

# %% [markdown]
# ---
#
# ###**Problem Description**
#
#
# **Task:** Given a set of points set of $n+1$ points $[(x_0,y_0),(x_1,y_1),\cdots,(x_n,y_n)]$ find the coeficients $a_0,a_1,\cdots,a_n$ of the Vandermonde intepolation polinomial
#
# $$
# P_n(x) = a_0 + a_1 x + \cdots + a_n x^n
# $$
#
#
#
# ---
#
# **Input Format:** A list  of $n+1$ points $[(x_0,y_0),(x_1,y_1),\cdots,(x_n,y_n)]$ with ecah points a tuple $(x,y)$.
#
# **Constraints:** $1 \leq n \leq 10^4$.
#
# **Output Format:** The list  of the $n+1$  vandermonde polynomial coeficents $[a_0,a_1,\cdots,a_n]$.
#
# ---

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
#
# Vander([(0, 6), (1, 1), (2, 8)])
#
# #  --> Expected output: [6.0, -11.0, 6.0]
#
# Vander([(0, 6), (1, 0), (2, 5), (3, 4)])
#
# #  --> Expected output: [6.0, -17.16667, 14.0, -2.83333]
#
# Vander([(0, 0), (1, 2), (2, 10), (3, 30)])
#
# #  --> Expected output: [0.0, 1.0, -0.0, 1.0]
#
# ```
#
# ---

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def Vander(points):
 
  #Your code goes here


  # a = [a_0,a_1,...,a_n]  the  list  of the $n+1$  vandermonde polynomial coeficents
  return [round(c,5) for c in a]

# %% [markdown]
# #**|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||**#

# %% [markdown]
# # **2. Calculate the approximate *area* inside of the parametric polar curve**
#
# $$ r = 1- \cos(a\theta) \sin(b\theta) $$
#
# # **using the quadrature  *Q(N)* with the left valuesand the *absolute error* respect to the *quad* integrator from *scipy.integrate***

# %% [markdown]
# ### Polar Curves - Brilliant
# https://brilliant.org/wiki/polar-curves/
#
# ![PolarCurvesBrilliant.png](https://raw.githubusercontent.com/gjhernandezp/algorithms/master/Montercarlo/PolarCurvesBrilliant.png)

# %% [markdown]
# ### Area inside of polar curve - UT Calculus
#
# * https://web.ma.utexas.edu/users/m408s/m408d/CurrentWeb/LM10-4-2.php
#
# ![IntPolarCurvesUTCalculus.png](https://raw.githubusercontent.com/gjhernandezp/algorithms/master/Montercarlo/IntPolarCurvesUTCalculus.png)

# %% [markdown]
# ### Quadrature rule *Q(N)*
#
# ![](https://metnumun.files.wordpress.com/2021/07/image-25.png)

# %% [markdown]
# ---
#
# ###**Problem Description**
#
#
# **Task:** Given an integer $N$, calcualte the approximate area inside of the parametric polar curve $ r = 1- \cos(a\theta) \sin(b\theta) $ using the quadrature  *Q(N)* with the left values.
#
# **Input Format:** The input consists of two floats $a$ and $b$ and an integer $N$.
#
# **Constraints:** $1 \leq n \leq 1000$.
#
# **Output Format:** Approximate area rounded to 4 deicmal digits.
#
# **Hint:** Check the notebook [MontecarloAreas.ipynb](https://github.com/gjhernandezp/algorithms/blob/master/Montercarlo/MontecarloAreas.ipynb)
#
# ---

# %% [markdown]
# **Sample testcase**
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# polar_quadrature(1,3,2)
# #  --> Expected output: (3.1416, 0.7854)
# ```
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# polar_quadrature(3,15,5)
# #  --> Expected output: (3.1416, 0.7854)
# ```
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# polar_quadrature(3,15,10)
# #  --> Expected output:   (3.5343, 0.3927)
# ```
#
# ```python
# #run this sample testcase on a cell to help you validate your solution
# polar_quadrature(3,15,100)
# #  --> Expected output:   (3.927, 0.0)
# ```
#
# ---

# %% [markdown]
# **Solution**

# %%
#Do not change this function's name, parameters or output format. It will be used in automatic grading.

def polar_quadrature(a,b,N):
  
  area = 0.0
  error = 0.0

  return round(area,4), round(error,4)
