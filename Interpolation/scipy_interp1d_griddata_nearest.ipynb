# %% [markdown]
# SciPy - One-dimensional nearest interpolation (scipy.interpolate.interp1d  kind='nearest')
#
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html
#
# * https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html

# %%
import numpy as np
from scipy.interpolate import interp1d

x = np.linspace(0, 10, num=11, endpoint=True)
y = np.cos(-x**2/9.0)
f1 = interp1d(x, y, kind='nearest')
f2 = interp1d(x, y, kind='previous')
f3 = interp1d(x, y, kind='next')

xnew = np.linspace(0, 10, num=1001, endpoint=True)
import matplotlib.pyplot as plt
plt.plot(x, y, 'o')
plt.plot(xnew, f1(xnew), '-', xnew, f2(xnew), '--', xnew, f3(xnew), ':')
plt.legend(['data', 'nearest', 'previous', 'next'], loc='best')
plt.show()

# %%
xs = np.linspace(0, 10, num=1001, endpoint=True)
ys = np.cos(-xs**2/9.0)
import matplotlib.pyplot as plt
plt.plot(xs, ys)
plt.show()

# %% [markdown]
# SciPy - Two-dimensional interpolation - Interpolate unstructured D-D data.
#
# * scipy.interpolate.griddata https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.griddata.html
#
# * numpy.mgrid https://numpy.org/doc/stable/reference/generated/numpy.mgrid.html
#
# * matplotlib.pyplot.imshow https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.imshow.html
#
# * Interpolations for imshow https://matplotlib.org/3.3.3/gallery/images_contours_and_fields/interpolation_methods.html

# %%
def func(x, y):
    return x*(1-x)*np.cos(4*np.pi*x) * np.sin(4*np.pi*y**2)**2

grid_x, grid_y = np.mgrid[0:1:100j, 0:1:200j]

points = np.random.rand(1000, 2)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')
grid_z1 = griddata(points, values, (grid_x, grid_y), method='linear')
grid_z2 = griddata(points, values, (grid_x, grid_y), method='cubic')

import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(121)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(122)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')

plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(222)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.subplot(223)
plt.imshow(grid_z1.T, extent=(0,1,0,1), origin='lower')
plt.title('Linear')
plt.subplot(224)
plt.imshow(grid_z2.T, extent=(0,1,0,1), origin='lower')
plt.title('Cubic')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
def func(x, y):
    return np.cos(np.pi*x) * np.sin(np.pi*y)

grid_x, grid_y = np.mgrid[0:1:100j, 0:1:100j]

points = np.random.rand(10, 2)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')
grid_z1 = griddata(points, values, (grid_x, grid_y), method='linear')
grid_z2 = griddata(points, values, (grid_x, grid_y), method='cubic')

import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(121)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(122)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')

plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(222)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.subplot(223)
plt.imshow(grid_z1.T, extent=(0,1,0,1), origin='lower')
plt.title('Linear')
plt.subplot(224)
plt.imshow(grid_z2.T, extent=(0,1,0,1), origin='lower')
plt.title('Cubic')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
def func(x, y):
    return np.cos(np.pi*x) * np.sin(np.pi*y)

grid_x, grid_y = np.mgrid[0:1:10j, 0:1:10j]

points = np.random.rand(80, 2)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')
grid_z1 = griddata(points, values, (grid_x, grid_y), method='linear')
grid_z2 = griddata(points, values, (grid_x, grid_y), method='cubic')

import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(121)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(122)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')

plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(222)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.subplot(223)
plt.imshow(grid_z1.T, extent=(0,1,0,1), origin='lower')
plt.title('Linear')
plt.subplot(224)
plt.imshow(grid_z2.T, extent=(0,1,0,1), origin='lower')
plt.title('Cubic')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %%
def func(x, y):
    return np.cos(np.pi*x) * np.sin(np.pi*y)

grid_x, grid_y = np.mgrid[0:1:100j, 0:1:100j]

#points = np.random.rand(2, 2)


points = np.array([[0.25, 0.25],[0.75,0.75]])
print(points)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')


import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(222)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')
plt.subplot(223)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(224)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.gcf().set_size_inches(6, 6)
plt.show()
# Out:
# [[0.25 0.25]
#  [0.75 0.75]]

# %%
def func(x, y):
    return np.cos(np.pi*x) * np.sin(np.pi*y)

grid_x, grid_y = np.mgrid[0:1:100j, 0:1:100j]

#points = np.random.rand(2, 2)


points = np.array([[0.25, 0.25],[0.5, 0.95],[0.75, 0.25]])
print(points)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')


import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(222)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')
plt.subplot(223)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(224)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.gcf().set_size_inches(6, 6)
plt.show()
# Out:
# [[0.25 0.25]
#  [0.5  0.95]
#  [0.75 0.25]]

# %%
def func(x, y):
    return np.cos(np.pi*x) * np.sin(np.pi*y)

grid_x, grid_y = np.mgrid[0:1:100j, 0:1:100j]

#points = np.random.rand(2, 2)


points = np.array([[0.25, 0.25],[0.4, 0.8],[0.75, 0.25],[0.85, 0.85]])
print(points)
values = func(points[:,0], points[:,1])

from scipy.interpolate import griddata
grid_z0 = griddata(points, values, (grid_x, grid_y), method='nearest')


import matplotlib.pyplot as plt

def  cons(x, y):
    return np.ones_like(x) * np.ones_like(y)

    
plt.subplot(221)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.title('Original')
plt.subplot(222)
plt.imshow(cons(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Random points')
plt.subplot(223)
plt.imshow(func(grid_x, grid_y).T, extent=(0,1,0,1), origin='lower')
plt.plot(points[:,0], points[:,1], 'w.', ms=1)
plt.title('Original sampled')
plt.subplot(224)
plt.imshow(grid_z0.T, extent=(0,1,0,1), origin='lower')
plt.title('Nearest')
plt.gcf().set_size_inches(6, 6)
plt.show()
# Out:
# [[0.25 0.25]
#  [0.4  0.8 ]
#  [0.75 0.25]
#  [0.85 0.85]]

# %% [markdown]
# Two-dimensional interpolation with scipy.interpolate.griddata
# https://scipython.com/book/chapter-8-scipy/examples/two-dimensional-interpolation-with-scipyinterpolategriddata/

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt

x = np.linspace(-1,1,100)
y =  np.linspace(-1,1,100)
X, Y = np.meshgrid(x,y)

def f(x, y):
    s = np.hypot(x, y)
    phi = np.arctan2(y, x)
    tau = s + s*(1-s)/5 * np.sin(6*phi) 
    return 5*(1-tau) + tau

T = f(X, Y)
# Choose npts random point from the discrete domain of our model function
npts = 400
px, py = np.random.choice(x, npts), np.random.choice(y, npts)

fig, ax = plt.subplots(nrows=2, ncols=2)
# Plot the model function and the randomly selected sample points
ax[0,0].contourf(X, Y, T)
ax[0,0].scatter(px, py, c='k', alpha=0.2, marker='.')
ax[0,0].set_title('Sample points on f(X,Y)')

# Interpolate using three different methods and plot
for i, method in enumerate(('nearest', 'linear', 'cubic')):
    Ti = griddata((px, py), f(px,py), (X, Y), method=method)
    r, c = (i+1) // 2, (i+1) % 2
    ax[r,c].contourf(X, Y, Ti)
    ax[r,c].set_title("method = '{}'".format(method))

plt.tight_layout()
plt.show()
